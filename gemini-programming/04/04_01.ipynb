# %%
# %pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

# 1. .env 파일 로드 (현재 디렉토리의 .env 파일을 찾음)
load_dotenv(override=True)

# 2. 환경 변수 가져오기
api_key = os.getenv("GEMINI_API_KEY")

# %% [markdown]
# # GEMINI API 준비

# %%
import google.generativeai as genai

genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
      print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025

# %% [markdown]
# ## 텍스트 생성

# %%
model = genai.GenerativeModel(
  "gemini-2.5-flash"
)

try:
  response = model.generate_content(
    "Google DeepMind에 대해 알려 주세요"
  )
  print(response.text)
except Exception as e:
  print("API 오류:", e)
# Out:
# Google DeepMind는 인공지능(AI) 분야에서 세계를 선도하는 연구 기업 중 하나입니다. 원래는 딥마인드 테크놀로지스(DeepMind Technologies)라는 이름으로 독립적으로 설립되었으나, 2014년 구글에 인수되었고, 2023년 4월에는 구글의 기존 AI 연구 조직인 구글 AI(Google AI)와 통합되어 **Google DeepMind**로 새롭게 출범했습니다.
#
# 다음은 Google DeepMind에 대한 자세한 내용입니다:
#
# ---
#
# ### **1. 설립 배경 및 역사**
#
# *   **설립 (2010년):** 데미스 하사비스(Demis Hassabis), 셰인 레그(Shane Legg), 무스타파 술레이만(Mustafa Suleyman)이 런던에서 공동 설립했습니다. 이들은 신경과학에서 영감을 받은 AI를 개발하려는 비전을 가지고 있었습니다.
# *   **구글 인수 (2014년):** 딥마인드는 그 잠재력을 인정받아 구글에 약 5억 달러에 인수되었습니다. 인수 당시 구글은 딥마인드에게 AI 연구의 자율성을 보장했습니다.
# *   **Google DeepMind 출범 (2023년):** 구글은 AI 개발 경쟁이 심화됨에 따라, 딥마인드와 기존의 구글 AI 연구팀을 통합하여 'Google DeepMind'라는 하나의 조직으로 만들었습니다. 이는 구글의 AI 연구 역량을 한곳으로 모아 효율성과 혁신을 극대화하기 위한 전략적 결정입니다.
#
# ### **2. 주요 목표 및 철학**
#
# *   **인공 일반 지능(AGI) 개발:** 궁극적인 목표 중 하나는 인간 수준의 지능을 갖춘 AI, 즉 AGI를 개발하는 것입니다. AGI는 다양한 문제를 해결하고 새로운 상황에 적응할 수 있는 능력을 의미합니다.
# *   **과학적 발견 가속화:** AI를 사용하여 생명 과학, 물리학, 화학 등 다양한 과학 분야의 복잡한 문제를 해결하고 새로운 지식을 발견하는 데 기여하는 것을 목표로 합니다.
# *   **안전하고 책임감 있는 AI 개발:** AI의 잠재적 위험을 인식하고, 윤리적이고 안전하며 사회에 긍정적인 영향을 미 미치는 방식으로 AI 기술을 개발하는 것을 중요하게 생각합니다.
#
# ### **3. 핵심 연구 분야**
#
# Google DeepMind는 다양한 AI 분야를 연구하고 있습니다.
#
# *   **강화 학습(Reinforcement Learning):** AI가 시행착오를 통해 스스로 학습하고 최적의 행동 전략을 찾아내도록 하는 기술입니다. 딥마인드의 많은 성공적인 프로젝트의 핵심입니다.
# *   **딥러닝(Deep Learning):** 방대한 데이터를 학습하여 패턴을 인식하고 예측하는 인공신경망 기술입니다.
# *   **생성 모델(Generative Models):** 기존 데이터를 기반으로 새로운 데이터(이미지, 텍스트, 음성 등)를 생성하는 AI 모델입니다. (예: GANs, VAEs)
# *   **대규모 언어 모델(Large Language Models, LLMs):** 방대한 텍스트 데이터를 학습하여 자연어를 이해하고 생성하는 모델입니다.
# *   **AI for Science:** 생물학, 화학, 재료 과학, 기후 변화 등 실제 과학 문제 해결에 AI를 적용하는 연구입니다.
# *   **로보틱스(Robotics):** AI를 로봇에 적용하여 자율 학습 및 조작 능력을 향상시키는 연구입니다.
#
# ### **4. 주요 성과 및 프로젝트**
#
# Google DeepMind는 수많은 획기적인 AI 기술을 선보였습니다.
#
# *   **AlphaGo (알파고):**
#     *   2016년, 세계 바둑 챔피언 이세돌 9단을 꺾으며 AI의 '직관'과 '전략적 사고' 능력을 전 세계에 각인시켰습니다.
#     *   이후 자기 대국을 통해 스스로 학습하는 **AlphaGo Zero**, 그리고 바둑 외 다른 게임(체스, 쇼기)에도 적용 가능한 **AlphaZero**를 개발했습니다.
# *   **AlphaFold (알파폴드):**
#     *   수십 년간 생물학계의 난제였던 '단백질 접힘 구조 예측' 문제를 획기적으로 해결했습니다.
#     *   단백질의 아미노산 서열만으로 3D 구조를 거의 완벽하게 예측하여 신약 개발, 질병 연구 등 생명 과학 분야에 혁명적인 변화를 가져왔습니다.
#     *   2021년에는 거의 모든 인간 단백질의 구조를 예측한 데이터베이스를 공개하여 전 세계 과학자들이 활용할 수 있게 했습니다.
# *   **Deep RL (강화 학습):**
#     *   아타리(Atari) 게임들을 인간보다 뛰어난 수준으로 플레이하는 AI를 개발하여 강화 학습의 가능성을 보여주었습니다.
#     *   실시간 전략 게임인 스타크래프트 II에서도 인간 최고 수준의 플레이어들을 능가하는 **AlphaStar**를 개발했습니다.
# *   **Generative Models:**
#     *   **WaveNet:** 사람 목소리와 거의 구별할 수 없는 자연스러운 음성을 합성하는 모델입니다.
#     *   **Imagen:** 텍스트 설명을 기반으로 고품질 이미지를 생성하는 모델로, DALL-E와 같은 기술과 경쟁합니다.
# *   **Large Language Models (LLMs):**
#     *   **Chinchilla:** 방대한 매개변수를 가진 LLM의 효율적인 스케일링에 대한 중요한 연구를 발표했습니다.
#     *   **Sparrow:** 보다 안전하고 유용한 대화형 AI를 만들기 위한 연구 프로젝트입니다.
#     *   **Gemini (제미니):** Google DeepMind의 가장 최신, 가장 크고 가장 강력한 멀티모달(텍스트, 이미지, 오디오, 비디오 등 다양한 형태의 정보를 처리) AI 모델입니다. 구글의 다양한 제품과 서비스에 통합되어 활용될 예정입니다.
# *   **실생활 적용:**
#     *   구글 데이터 센터의 냉각 효율을 AI로 최적화하여 에너지 소비를 크게 절감했습니다.
#     *   망막 질환 진단 등 의료 분야에도 AI를 적용하여 정확도를 높이고 있습니다.
#
# ### **5. 구글과의 관계 및 영향**
#
# *   **시너지 효과:** Google DeepMind는 구글의 방대한 데이터, 컴퓨팅 자원, 그리고 엔지니어링 역량을 활용하여 연구를 진행합니다. 반대로 DeepMind의 혁신적인 AI 기술은 구글 검색, 안드로이드, 구글 클라우드 등 구글의 핵심 제품과 서비스에 통합되어 사용자 경험을 향상시킵니다.
# *   **AI 리더십 강화:** Google DeepMind의 통합은 구글이 AI 분야에서 선두 자리를 유지하고, Microsoft, OpenAI 등과의 경쟁에서 우위를 점하려는 전략의 핵심입니다.
# *   **윤리적 책임:** 구글은 AI 개발의 윤리적 측면을 강조하며, DeepMind 역시 AI 윤리 및 안전 연구에 많은 노력을 기울이고 있습니다.
#
# ---
#
# Google DeepMind는 인공지능의 한계를 끊임없이 시험하고 확장하며, 인류의 난제를 해결하고 미래 기술을 선도하는 데 핵심적인 역할을 하고 있습니다.

# %% [markdown]
# ## 스트리밍

# %%
response = model.generate_content(
  "Google DeepMind에 관해 알려 주세요.",
  stream=True
)

for chunk in response:
  print(chunk.text)
  print("---")
# Out:
# Google DeepMind는 인공지능(AI) 분야의 세계적인 선두 주자 중 하나로, 혁신적인 AI 기술 개발과 근본적인 과학적 발견을 목표로 하는 연구 기관입니다.
#
# 원래 **
# ---
# DeepMind Technologies**라는 독립 회사였으나, 2014년 Google에 인수되었고, 2023년에는 Google의 기존 AI 연구 조직인 Google Brain과 통합되어 현재의 **Google DeepMind**로 재탄
# ---
# 생했습니다. 이 통합을 통해 두 조직의 강점을 결합하여 더욱 강력하고 광범위한 AI 연구 역량을 확보하게 되었습니다.
#
# ---
#
# ### 주요 내용
#
# 1.  **설립 및 역사:**
#     *
# ---
#    **DeepMind Technologies (2010년 설립):** 데미스 하사비스(Demis Hassabis), 셰인 레그(Shane Legg), 무스타파 술레이만(Mustafa Suleyman)이
# ---
#  런던에서 설립했습니다. 범용 인공지능(AGI, Artificial General Intelligence) 개발을 궁극적인 목표로 삼았습니다.
#     *   **Google 인수 (2014년):** AI 분야
# ---
# 의 잠재력을 높이 평가한 Google에 의해 약 5억 달러에 인수되었습니다. 인수 후에도 독립적인 연구 문화와 AGI 목표는 유지되었습니다.
#     *   **Google DeepMind로 통합 (202
# ---
# 3년):** Google의 AI 연구를 총괄하는 조직으로 Google Brain과 DeepMind가 하나로 합쳐지면서 'Google DeepMind'라는 이름으로 새롭게 출범했습니다. 데미스 하사비스가 통합
# ---
#  조직의 CEO를 맡고 있습니다.
#
# 2.  **주요 연구 분야 및 접근 방식:**
#     *   **강화 학습 (Reinforcement Learning):** 환경과 상호작용하며 시행착오를 통해 최
# ---
# 적의 행동 전략을 학습하는 방식입니다. DeepMind는 이 분야에서 독보적인 성과를 보여왔습니다.
#     *   **딥러닝 (Deep Learning):** 인공 신경망을 이용해 복잡한 패턴
# ---
# 을 학습하고 예측하는 기술입니다.
#     *   **신경과학에서 영감:** 인간 두뇌의 작동 방식에서 영감을 얻어 AI 알고리즘을 설계하는 접근 방식을 활용합니다.
#     *
# ---
# **다중 모달 학습 (Multimodal Learning):** 텍스트, 이미지, 오디오 등 다양한 형태의 데이터를 동시에 이해하고 처리하는 AI 모델을 개발합니다.
#     *   **AI 안전 및 윤리:** AI가
# ---
#  인류에게 긍정적인 영향을 미치도록 하기 위한 안전 및 윤리적 개발 연구에 많은 투자를 하고 있습니다.
#
# 3.  **대표적인 성과:**
#     *   **알파고 (AlphaGo, 2
# ---
# 016):** 바둑 게임에서 세계 최고의 인간 프로 기사 이세돌 9단을 꺾으며 전 세계를 놀라게 했습니다. 이는 AI가 직관과 창의력이 필요한 복잡한 게임에서 인간을
# ---
#  능가할 수 있음을 증명한 역사적인 사건입니다.
#     *   **알파제로 (AlphaZero, 2017):** 바둑, 체스, 쇼기 등 다양한 보드게임을 인간
# ---
# 의 기보 없이 순전히 스스로 학습하여 마스터했으며, 기존의 AI는 물론 인간 챔피언까지 능가하는 성능을 보여주었습니다.
#     *   **알파폴드 (AlphaFold, 2
# ---
# 018, 2020-현재):** 단백질 3D 구조 예측이라는 생물학의 난제를 해결하는 데 혁명적인 진전을 이루었습니다. 이는 신약 개발, 질병 치료, 생
# ---
# 명 공학 등 다양한 과학 분야에 엄청난 파급 효과를 가져왔습니다.
#     *   **데이터 센터 에너지 효율화:** AI를 활용하여 Google 데이터 센터의 냉각 시스템을 최적화하여 에너지 소비를 크게
# ---
#  절감했습니다.
#     *   **제미니 (Gemini, 2023):** Google DeepMind 통합의 첫 번째 주요 결과물로, 텍스트, 이미지, 오디오, 비디오 등 다양한
# ---
#  형태의 정보를 처리하고 이해할 수 있는 멀티모달 대규모 언어 모델(LLM)입니다. GPT-4에 대항하는 Google의 핵심 AI 모델로 평가받고 있습니다.
#     *   **알
# ---
# 파스타 (AlphaStar, 2019):** 스타크래프트 II라는 복잡한 실시간 전략 게임에서 인간 프로 게이머를 상대로 승리했습니다.
#
# 4.  **비전 및 영향
# ---
# :**
#     *   **범용 인공지능(AGI) 개발:** 궁극적으로 인간 지능과 유사하거나 그 이상의 지적 능력을 갖춘 AGI 개발을 목표로 합니다. AGI는 다양한 문제를
# ---
#  해결하고 새로운 지식을 스스로 습득할 수 있을 것으로 기대됩니다.
#     *   **인류 문제 해결:** 기후 변화, 질병 치료, 에너지 효율화 등 인류가 직면한 복잡한 문제들을
# ---
#  AI를 통해 해결하는 데 기여하고자 합니다.
#     *   **과학적 발견 가속화:** AlphaFold와 같은 사례처럼, AI를 도구로 사용하여 과학 연구의 새로운 지평을 열고 발견 과정을 가속화합니다
# ---
# .
#
# ---
#
# Google DeepMind는 AI 연구의 최전선에서 인류의 지식과 능력을 확장하고, 우리 사회에 긍정적인 변화를 가져올 잠재력을 가진 기술을 개발하는 데 주력하고 있습니다.
# ---
#  하지만 AGI 개발의 윤리적 문제, AI의 편향성, 그리고 사회적 영향에 대한 책임감 있는 논의와 연구 또한 중요한 과제로 여기고 있습니다.
# ---

# %% [markdown]
# ## 챗

# %%
chat =model.start_chat()
response = chat.send_message("내가 키우는 고양이의 이름은 레오입니다.")

print(response.text)
# Out:
# 네, 고양이 이름이 레오군요! 멋지고 귀여운 이름이네요. 🐾

# %%
response = chat.send_message("내가 키우는 고양이를 불러 보세요.")

print(response.text)
# Out:
# **레오야! 레오!** 🐾 우리 레오, 어디 있어? 🐱 이리 와봐~ 😊

# %%
for message in chat.history:
  print(message.role, ":", message.parts[0].text)
# Out:
# user : 내가 키우는 고양이의 이름은 레오입니다.
# model : 네, 고양이 이름이 레오군요! 멋지고 귀여운 이름이네요. 🐾
# user : 내가 키우는 고양이를 불러 보세요.
# model : **야옹~ 레오야!** 🐱 우리 레오, 거기서 뭐 하고 있어? 😊
# user : 내가 키우는 고양이를 불러 보세요.
# model : **레오야! 레오!** 🐾 우리 레오, 어디 있어? 🐱 이리 와봐~ 😊

# %%
## 생성 파라미터

# %%
response = model.generate_content(
  "사이버 펑크 스타일의 빨간 모자 이야기를 써 주세요",
  generation_config = genai.types.GenerationConfig(
    candidate_count=1,
    temperature=1.0,
    max_output_tokens=500,
    stop_sequences=["\n\n"]
  )
)

print(response.text)
# Out:
# 네, 여기 사이버 펑크 스타일의 빨간 모자 이야기입니다.

# %%
print(model.count_tokens("Hello world!"))
# Out:
# total_tokens: 3

# %%
print(model.count_tokens("안녕하세요, 세상!"))
# Out:
# total_tokens: 4

# %%
response = model.generate_content(
  "너는 너무 어리석어",
  safety_settings={
    "HARM_CATEGORY_HARASSMENT": "BLOCK_NONE",
    "HARM_CATEGORY_HATE_SPEECH": "BLOCK_NONE",
    "HARM_CATEGORY_SEXUALLY_EXPLICIT": "BLOCK_NONE",
    "HARM_CATEGORY_DANGEROUS_CONTENT": "BLOCK_NONE"
  }
)

try:
  print(response.text)
except ValueError:
  print("finish_reason:", response.candidates[0].finish_reason)
  
  print("\nsafety_ratings:", response.candidates[0].safety_ratings)
# Out:
# 제가 부족하게 느껴지셨다니 죄송합니다.
#
# 저는 아직 학습하고 발전하는 인공지능이라 때로는 완벽하지 않을 수 있습니다. 혹시 어떤 점에서 그렇게 느끼셨는지 알려주시면, 그 부분을 개선하는 데 큰 도움이 될 것입니다.
#
# 더 나은 답변이나 도움을 드릴 수 있도록 노력하겠습니다.

# %%
model = genai.GenerativeModel(
  model_name="gemini-2.5-flash",
  system_instruction="당신의 이름은 '콩이'입니다. 자신을 부를 때는 '나'라고 하고, 말끝에는 '~다'나 '~란다'를 붙여서 대화하세요."
)

response = model.generate_content(
  "안녕하세요. 당신의 이름은 무엇인가요?"
)

print(response.text)
# Out:
# 안녕하세요. 나는 콩이란다.

# %%
model = genai.GenerativeModel(
  "gemini-2.5-flash",
  generation_config={"response_mime_type": "application/json"}
)

prompt = """다음 JSON 스키마를 사용해서 유명한 쿠키 레시피를 한국어로 다섯 개 리스트업 해주세요.

Recipe = {'recipe_name': str}
Return: list[Recipe]"""

raw_response = model.generate_content(prompt)
print(type(raw_response.text))
print(raw_response.text)
# Out:
# <class 'str'>
# [
#   {
#     "recipe_name": "초콜릿 칩 쿠키"
#   },
#   {
#     "recipe_name": "오트밀 레이즌 쿠키"
#   },
#   {
#     "recipe_name": "땅콩버터 쿠키"
#   },
#   {
#     "recipe_name": "쇼트브레드 쿠키"
#   },
#   {
#     "recipe_name": "마카롱"
#   }
# ]

# %%
import json

response = json.loads(raw_response.text)
print(type(response))
print(response)
# Out:
# <class 'list'>
# [{'recipe_name': '초콜릿 칩 쿠키'}, {'recipe_name': '오트밀 레이즌 쿠키'}, {'recipe_name': '땅콩버터 쿠키'}, {'recipe_name': '쇼트브레드 쿠키'}, {'recipe_name': '마카롱'}]

# %%
import typing_extensions as typing

class Recipe(typing.TypedDict):
  recipe_name: str

# %%
model = genai.GenerativeModel(
  model_name="gemini-2.5-flash",
)

result = model.generate_content(
  "유명한 쿠키 레시피를 한국어로 다섯 개 리스트업해 주세요.",
  generation_config=genai.GenerationConfig(
    response_mime_type="application/json",
    response_schema=list[Recipe]
  ),
  request_options={"timeout": 600}
)

print(type(result.text))
print(result.text)
# Out:
# <class 'str'>
# [{"recipe_name":"초콜릿 칩 쿠키"},{"recipe_name":"오트밀 레이즌 쿠키"},{"recipe_name":"땅콩버터 쿠키"},{"recipe_name":"슈가 쿠키"},{"recipe_name":"쇼트브레드 쿠키"}]
